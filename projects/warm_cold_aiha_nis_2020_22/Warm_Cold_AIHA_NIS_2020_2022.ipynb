# %% [markdown]
# # Warm and Cold AIHA — NIS 2020–2022
#
# This is the primary runnable notebook for the new AIHA project. Choose Run → Run All Cells.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path.cwd()
if not (REPO_ROOT / 'projects').exists(): REPO_ROOT = REPO_ROOT.parents[1]
os.chdir(REPO_ROOT)
if str(REPO_ROOT) not in sys.path: sys.path.insert(0, str(REPO_ROOT))
from projects.warm_cold_aiha_nis_2020_22.analysis import main
results = main()
print('AIHA cohort-yield analysis completed.')
# Out:
# {
#   "project": "Warm and Cold AIHA NIS 2020\u20132022",
#   "regression_reference_group": "Warm AIHA",
#   "regression_comparison_group": "Cold AIHA",
#   "all_adult_denominators": [
#     {
#       "admission_year": 2020,
#       "unweighted_all_adult_hospitalizations": 5533477,
#       "weighted_all_adult_hospitalizations": 27667386
#     },
#     {
#       "admission_year": 2021,
#       "unweighted_all_adult_hospitalizations": 5688355,
#       "weighted_all_adult_hospitalizations": 28441739
#     },
#     {
#       "admission_year": 2022,
#       "unweighted_all_adult_hospitalizations": 5571320,
#       "weighted_all_adult_hospitalizations": 27856590
#     },
#     {
#       "admission_year": "Total",
#       "unweighted_all_adult_hospitalizations": 16793152,
#       "weighted_all_adult_hospitalizations": 83965715
#     }
#   ],
#   "all_specified_aiha_codes_top_three": [
#     {
#       "definition": "D59.10 \u2014 Autoimmune hemolytic anemia, unspecified",
# ...

# %% [markdown]
# ## Preliminary cohort-yield report

# %%
from IPython.display import Markdown, display
report_path = REPO_ROOT / 'projects/warm_cold_aiha_nis_2020_22/report.md'
display(Markdown(report_path.read_text()))
# Out:
# # Warm and Cold AIHA — NIS 2020–2022
#
# ## Preliminary cohort definition
#
# Population: all adult NIS hospitalizations (`AGE >= 18`) from 2020 through 2022. Warm AIHA is exact normalized `D59.11`; cold AIHA is exact normalized `D59.12`.
#
# **Regression reference category:** Warm AIHA. All future regression coefficients and odds ratios for AIHA type will compare cold AIHA with warm AIHA unless explicitly labeled otherwise.
#
# ## All Adult Hospitalization Denominators
#
# | Admission year | Unweighted adult hospitalizations | DISCWT-weighted adult hospitalizations |
# | --- | ---: | ---: |
# | 2020 | 5,533,477 | 27,667,386 |
# | 2021 | 5,688,355 | 28,441,739 |
# | 2022 | 5,571,320 | 27,856,590 |
# | Total | 16,793,152 | 83,965,715 |
#
# ## Primary-diagnosis definition
#
# | Phenotype | Unweighted hospitalizations | DISCWT-weighted hospitalizations |
# | --- | ---: | ---: |
# | Warm AIHA (D59.11) | 571 | 2,855 |
# | Cold AIHA (D59.12) | 232 | 1,160 |
# ...

# %% [markdown]
# ## Warm Versus Cold AIHA Baseline Characteristics
#
# Weighted demographic, hospital, CCI, length-of-stay, and mortality comparison; warm AIHA is the reference group.

# %%
from projects.warm_cold_aiha_nis_2020_22.baseline import main as run_baseline
baseline_results = run_baseline()
baseline_report = REPO_ROOT / 'projects/warm_cold_aiha_nis_2020_22/outputs/warm_vs_cold_baseline_characteristics_report.md'
display(Markdown(baseline_report.read_text()))
# Out:
# {
#   "warm_n": 811,
#   "cold_n": 568,
#   "report": "/Users/evelynzhang/Desktop/dev/IPC-MPC-Study/projects/warm_cold_aiha_nis_2020_22/outputs/warm_vs_cold_baseline_characteristics_report.md"
# }
# # Warm Versus Cold AIHA: Baseline Characteristics
#
# Warm AIHA is the reference group. Percentages, means, standard deviations, and displayed weighted counts use `DISCWT`. P-values are Welch tests for continuous variables and overall Pearson chi-square tests for categorical variables; missing levels are excluded from categorical tests.
#
# The Charlson Comorbidity Index uses all diagnosis positions, standard Quan ICD-10 components and weights, cancer/metastatic-cancer and diabetes/liver hierarchy, and no age points.
#
# | Characteristic | Level | Warm unweighted n | Warm weighted summary | Cold unweighted n | Cold weighted summary | Difference, pp | SMD | P-value | Test |
# | --- | --- | ---: | ---: | ---: | ---: | ---: | ---: | ---: | --- |
# ...

# %% [markdown]
# ## Any Lymphoid Malignancy
#
# Composite lymphoid-malignancy phenotype across all diagnosis positions, using prior-project ICD-10-CM rules.

# %%
from projects.warm_cold_aiha_nis_2020_22.lymphoid_malignancy import main as run_lymphoid
lymphoid_results = run_lymphoid()
lymphoid_report = REPO_ROOT / 'projects/warm_cold_aiha_nis_2020_22/outputs/any_lymphoid_malignancy_report.md'
display(Markdown(lymphoid_report.read_text()))
# Out:
# {
#   "reference_group": "Warm AIHA",
#   "phenotype_config": "/Users/evelynzhang/Desktop/dev/IPC-MPC-Study/config/hm_phenotype_v0_1.json",
#   "rows": [
#     {
#       "malignancy_definition": "Lymphoma spectrum (Hodgkin, NHL, WM/MALT)",
#       "warm_unweighted_n": 42,
#       "warm_weighted_n": 210,
#       "warm_weighted_percent": 5.18,
#       "cold_unweighted_n": 89,
#       "cold_weighted_n": 445,
#       "cold_weighted_percent": 15.67,
#       "difference_percentage_points": 10.49,
#       "standardized_mean_difference": 0.348,
#       "p_value": "<0.001"
#     },
#     {
#       "malignancy_definition": "CLL/chronic leukemia group",
#       "warm_unweighted_n": 84,
#       "warm_weighted_n": 420,
#       "warm_weighted_percent": 10.36,
#       "cold_unweighted_n": 35,
#       "cold_weighted_n": 175,
#       "cold_weighted_percent": 6.16,
#       "difference_percentage_points": -4.2,
#       "standardized_mean_difference": -0.153,
#       "p_value": "0.006"
#     },
#     {
# ...

# %% [markdown]
# ## Acute Venous and Arterial Thrombosis
#
# Individual diagnosis families and ANY_VTE, ANY_ARTERIAL_THROMBOSIS, and ANY_ACUTE_THROMBOSIS composites across all diagnosis positions.

# %%
from projects.warm_cold_aiha_nis_2020_22.thrombosis import main as run_thrombosis
thrombosis_results = run_thrombosis()
thrombosis_report = REPO_ROOT / 'projects/warm_cold_aiha_nis_2020_22/outputs/acute_thrombosis_report.md'
display(Markdown(thrombosis_report.read_text()))
# Out:
# {
#   "reference_group": "Warm AIHA",
#   "rows": [
#     {
#       "diagnosis_family": "Acute pulmonary embolism",
#       "warm_unweighted_n": 29,
#       "warm_weighted_n": 145,
#       "warm_weighted_percent": 3.58,
#       "cold_unweighted_n": 9,
#       "cold_weighted_n": 45,
#       "cold_weighted_percent": 1.58,
#       "difference_percentage_points": -1.99,
#       "standardized_mean_difference": -0.126,
#       "p_value": "0.026",
#       "fdr_adjusted_p_value": "0.262"
#     },
#     {
#       "diagnosis_family": "Acute deep-vein thrombosis",
#       "warm_unweighted_n": 25,
#       "warm_weighted_n": 125,
#       "warm_weighted_percent": 3.08,
#       "cold_unweighted_n": 17,
#       "cold_weighted_n": 85,
#       "cold_weighted_percent": 2.99,
#       "difference_percentage_points": -0.09,
#       "standardized_mean_difference": -0.005,
#       "p_value": "0.924",
#       "fdr_adjusted_p_value": "0.924"
#     },
#     {
# ...

# %% [markdown]
# ## Selected complications: warm versus cold AIHA
#
# This rerunnable section compares AKI, acute respiratory failure, and sepsis using all diagnosis positions.

# %%
from projects.warm_cold_aiha_nis_2020_22.complications import main as run_complications
complication_results = run_complications()
complication_report = REPO_ROOT / 'projects/warm_cold_aiha_nis_2020_22/outputs/selected_complications_report.md'
display(Markdown(complication_report.read_text()))
# Out:
# {
#   "reference_group": "Warm AIHA",
#   "rows": [
#     {
#       "complication": "Acute kidney injury",
#       "icd_10_cm_definition": "N17*",
#       "warm_unweighted_n": 169,
#       "warm_weighted_n": 845,
#       "warm_weighted_percent": 20.84,
#       "cold_unweighted_n": 92,
#       "cold_weighted_n": 460,
#       "cold_weighted_percent": 16.2,
#       "difference_percentage_points": -4.64,
#       "standardized_mean_difference": -0.12,
#       "p_value": "0.030"
#     },
#     {
#       "complication": "Acute respiratory failure",
#       "icd_10_cm_definition": "J960*",
#       "warm_unweighted_n": 47,
#       "warm_weighted_n": 235,
#       "warm_weighted_percent": 5.8,
#       "cold_unweighted_n": 27,
#       "cold_weighted_n": 135,
#       "cold_weighted_percent": 4.75,
#       "difference_percentage_points": -1.04,
#       "standardized_mean_difference": -0.047,
#       "p_value": "0.398"
#     },
#     {
#       "complication": "Sepsis",
# ...

# %% [markdown]
# ## Consolidated unweighted comparison
#
# This section combines every variable calculated so far into a single report-friendly comparison of the sampled warm and cold AIHA hospitalizations.

# %%
from projects.warm_cold_aiha_nis_2020_22.unweighted_comparison import main as run_unweighted_comparison
unweighted_results = run_unweighted_comparison()
unweighted_report = REPO_ROOT / 'projects/warm_cold_aiha_nis_2020_22/outputs/all_variables_unweighted_warm_vs_cold_report.md'
display(Markdown(unweighted_report.read_text()))
# Out:
# {
#   "warm_n": 811,
#   "cold_n": 568,
#   "rows": 67,
#   "report": "/Users/evelynzhang/Desktop/dev/IPC-MPC-Study/projects/warm_cold_aiha_nis_2020_22/outputs/all_variables_unweighted_warm_vs_cold_report.md"
# }
# # Unweighted Comparison of Warm Versus Cold AIHA Hospitalizations
#
# This table reports the actual sampled NIS hospitalization records without applying `DISCWT`. Warm AIHA is the reference group. Continuous variables are shown as unweighted mean (SD); categorical and binary variables are shown as unweighted n (%).
#
# P-values are unweighted Welch t-tests for continuous variables, overall Pearson chi-square tests for multilevel categorical variables, and Pearson chi-square tests for binary diagnoses. A p-value shown on the first level of a multilevel variable applies to the variable overall.
#
# ## Demographic and clinical characteristics
#
# | Characteristic | Level | Warm AIHA | Cold AIHA | Difference, pp | P-value | Test |
# ...

# %% [markdown]
# ## Multivariable mortality model
#
# Warm AIHA is the reference exposure. The model adjusts for the prespecified demographic, malignancy, hospital, and comorbidity covariates.

# %%
from projects.warm_cold_aiha_nis_2020_22.mortality_model import main as run_mortality_model
mortality_model_results = run_mortality_model()
mortality_model_report = REPO_ROOT / 'projects/warm_cold_aiha_nis_2020_22/outputs/adjusted_mortality_logistic_regression_report.md'
display(Markdown(mortality_model_report.read_text()))
# Out:
# {
#   "primary_exposure": {
#     "variable": "Cold AIHA vs warm AIHA",
#     "adjusted_odds_ratio": 1.199,
#     "ci_lower": 0.598,
#     "ci_upper": 2.401,
#     "p_value": "0.609"
#   },
#   "diagnostics": {
#     "analysis_n": 1379,
#     "deaths": 39,
#     "warm_n": 811,
#     "warm_deaths": 22,
#     "cold_n": 568,
#     "cold_deaths": 17,
#     "parameters": 18,
#     "converged": true,
#     "aic": 349.78
#   },
#   "all_coefficients": [
#     {
#       "variable": "Intercept",
#       "adjusted_odds_ratio": 0.002,
#       "ci_lower": 0.0,
#       "ci_upper": 0.017,
#       "p_value": "<0.001"
#     },
#     {
#       "variable": "Cold AIHA vs warm AIHA",
#       "adjusted_odds_ratio": 1.199,
#       "ci_lower": 0.598,
#       "ci_upper": 2.401,
#       "p_value": "0.609"
#     },
#     {
#       "variable": "Sex: Female",
#       "adjusted_odds_ratio": 0.42,
#       "ci_lower": 0.207,
#       "ci_upper": 0.853,
#       "p_value": "0.016"
#     },
#     {
# ...

# %% [markdown]
# ## Multivariable length-of-stay model
#
# Warm AIHA is the reference exposure. Because LOS is continuous, this section uses linear regression with HC3 robust standard errors and the same adjustment set as the mortality model.

# %%
from projects.warm_cold_aiha_nis_2020_22.los_model import main as run_los_model
los_model_results = run_los_model()
los_model_report = REPO_ROOT / 'projects/warm_cold_aiha_nis_2020_22/outputs/adjusted_los_linear_regression_report.md'
display(Markdown(los_model_report.read_text()))
# Out:
# {
#   "primary_exposure": {
#     "variable": "Cold AIHA vs warm AIHA",
#     "adjusted_coefficient": -0.6,
#     "ci_lower": -1.436,
#     "ci_upper": 0.236,
#     "p_value": "0.160"
#   },
#   "diagnostics": {
#     "analysis_n": 1379,
#     "parameters": 18,
#     "r_squared": 0.0343,
#     "robust_covariance": "HC3",
#     "warm_unadjusted_mean_los": 6.57,
#     "cold_unadjusted_mean_los": 5.93
#   },
#   "all_coefficients": [
#     {
#       "variable": "Intercept",
#       "adjusted_coefficient": 3.424,
#       "ci_lower": 1.629,
#       "ci_upper": 5.219,
#       "p_value": "<0.001"
#     },
#     {
#       "variable": "Cold AIHA vs warm AIHA",
#       "adjusted_coefficient": -0.6,
#       "ci_lower": -1.436,
#       "ci_upper": 0.236,
#       "p_value": "0.160"
#     },
#     {
#       "variable": "Sex: Female",
#       "adjusted_coefficient": -0.399,
#       "ci_lower": -1.159,
#       "ci_upper": 0.361,
#       "p_value": "0.303"
#     },
#     {
# ...
