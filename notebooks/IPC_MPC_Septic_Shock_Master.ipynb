# %% [markdown]
# # IPC-MPC Study: Septic Shock Primary Exposure
#
# This is the primary runnable notebook for the revised analysis. The exposure is **documented septic shock**, defined as exact normalized ICD-10-CM code `R65.21` (`R6521`) in any diagnosis position. The adult HM cohort, mutually exclusive subtype assignment, `Z51.5` outcome, `DISCWT` weights, and `NIS_STRATUM` variance approach are unchanged.
#
# Choose **Run → Run All Cells**. The first code cell reruns and caches the complete analysis; each subsequent numbered cell presents a copy/paste-friendly result table. Every table ends with a total row, where applicable.

# %%
from pathlib import Path
import os, sys

REPO_ROOT = Path.cwd()
if not (REPO_ROOT / 'src').exists():
    REPO_ROOT = REPO_ROOT.parent
os.chdir(REPO_ROOT)
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from src.septic_shock_notebook import rerun_all, show_step
results = rerun_all()
print('Complete septic-shock analysis rerun finished successfully.')
# Out:
# {
#   "unit": "NIS inpatient discharge, not unique patient",
#   "no_sepsis_unweighted_n": 951721,
#   "no_sepsis_weighted_n": 4758603,
#   "sepsis_unweighted_n": 43271,
#   "sepsis_weighted_n": 216355,
#   "age_no_sepsis_mean_sd": "66.90 (16.30)",
#   "age_sepsis_mean_sd": "67.29 (14.75)",
#   "largest_absolute_standardized_differences": [
#     {
#       "characteristic": "HM subtype",
#       "level": "Acute myeloid leukemia",
#       "standardized_difference": 0.132
#     },
#     {
#       "characteristic": "Sex",
#       "level": "Male",
#       "standardized_difference": 0.1
#     },
#     {
#       "characteristic": "Sex",
#       "level": "Female",
#       "standardized_difference": -0.1
#     },
#     {
#       "characteristic": "HM subtype",
#       "level": "Myeloproliferative neoplasm",
#       "standardized_difference": -0.084
#     },
#     {
#       "characteristic": "Hospital location/teaching (stratum-derived)",
#       "level": "Rural",
# ...

# %% [markdown]
# ## 1. Cohort Definition

# %%
show_step(1)
# Out:
# | Cohort | Unweighted hospitalizations | Weighted hospitalizations |
# | --- | --- | --- |
# | No septic shock | 951721 | 4758603 |
# | Septic shock (R65.21) | 43271 | 216355 |
# | Total | 994992 | 4974958 |
# *Exposure is an exact normalized match to R6521 in any diagnosis position; one row represents one hospitalization.*

# %% [markdown]
# ## 2. Baseline Characteristics

# %%
show_step(2)
# Out:
# | characteristic | level | no_shock_unweighted_n | no_shock_weighted_n | no_shock_weighted_percent_or_mean_sd | septic_shock_unweighted_n | septic_shock_weighted_n | septic_shock_weighted_percent_or_mean_sd | difference_percentage_points | standardized_difference | p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Age, years | Weighted mean (SD) | 951721 | 4758603 | 66.90 (16.30) | 43271 | 216355 | 67.29 (14.75) |  | 0.025 | <0.001 |
# | Age group | 18–59 | 257881 | 1289405 | 27.10% | 10677 | 53385 | 24.67% | -2.42 | -0.055 | <0.001 |
# | Age group | 60 or older | 693840 | 3469199 | 72.90% | 32594 | 162970 | 75.33% | 2.42 | 0.055 |  |
# | Sex | Male | 522399 | 2611994 | 54.89% | 25896 | 129480 | 59.85% | 4.96 | 0.1 | <0.001 |
# | Sex | Female | 429082 | 2145409 | 45.08% | 17369 | 86845 | 40.14% | -4.94 | -0.1 |  |
# | Sex | Missing | 240 | 1200 | 0.03% | 6 | 30 | 0.01% | -0.01 | -0.008 |  |
# ...

# %% [markdown]
# ## 3. Clinical Outcomes

# %%
show_step(3)
# Out:
# | outcome | level | no_shock_weighted | septic_shock_weighted | p_value | test | no_shock_unweighted | septic_shock_unweighted |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | Charlson Comorbidity Index excluding cancer | Mean (SD) | 1.86 (1.90) | 2.27 (1.96) | <0.001 | Welch t-test | 1.86 (1.90) | 2.27 (1.96) |
# | Charlson category | 0 | 1,465,480 (30.80%) | 44,420 (20.53%) | <0.001 | Pearson chi-square | 293,096 (30.80%) | 8,884 (20.53%) |
# |  | 1–2 | 1,856,384 (39.01%) | 87,845 (40.60%) |  |  | 371,277 (39.01%) | 17,569 (40.60%) |
# |  | ≥3 | 1,436,739 (30.19%) | 84,090 (38.87%) |  |  | 287,348 (30.19%) | 16,818 (38.87%) |
# | Length of stay, days | Mean (SD) | 7.25 (8.73) | 14.40 (17.07) | <0.001 | Welch t-test | 7.25 (8.73) | 14.40 (17.07) |
# | In-hospital mortality | Died | 181,245 (3.81%) | 87,440 (40.44%) | <0.001 | Pearson chi-square | 36,249 (3.81%) | 17,488 (40.44%) |
# | Total | Hospitalizations | 4,758,603 | 216,355 | — | — | 951,721 | 43,271 |
# ...

# %% [markdown]
# ## 4. HM Subtype Distribution

# %%
show_step(4)
# Out:
# | characteristic | level | no_shock_unweighted_n | no_shock_weighted_n | no_shock_weighted_percent_or_mean_sd | septic_shock_unweighted_n | septic_shock_weighted_n | septic_shock_weighted_percent_or_mean_sd | difference_percentage_points | standardized_difference | p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | HM subtype | Lymphoma | 288275 | 1441375 | 30.29% | 13219 | 66095 | 30.55% | 0.26 | 0.006 | <0.001 |
# | HM subtype | Acute myeloid leukemia | 74307 | 371535 | 7.81% | 5075 | 25375 | 11.73% | 3.92 | 0.132 |  |
# | HM subtype | Chronic myeloid leukemia | 25629 | 128145 | 2.69% | 911 | 4555 | 2.11% | -0.59 | -0.038 |  |
# | HM subtype | CLL/chronic leukemia | 104344 | 521720 | 10.96% | 4493 | 22465 | 10.38% | -0.58 | -0.019 |  |
# | HM subtype | Acute lymphoblastic/unspecified acute leukemia | 30661 | 153305 | 3.22% | 1484 | 7420 | 3.43% | 0.21 | 0.012 |  |
# ...

# %% [markdown]
# ## 5. Admission Year

# %%
show_step(5)
# Out:
# | characteristic | level | no_shock_unweighted_n | no_shock_weighted_n | no_shock_weighted_percent_or_mean_sd | septic_shock_unweighted_n | septic_shock_weighted_n | septic_shock_weighted_percent_or_mean_sd | difference_percentage_points | standardized_difference | p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Admission year | 2016 | 138465 | 692325 | 14.55% | 5706 | 28530 | 13.19% | -1.36 | -0.039 | <0.001 |
# | Admission year | 2017 | 138011 | 690055 | 14.50% | 5693 | 28465 | 13.16% | -1.34 | -0.039 |  |
# | Admission year | 2018 | 140419 | 702095 | 14.75% | 6054 | 30270 | 13.99% | -0.76 | -0.022 |  |
# | Admission year | 2019 | 146472 | 732360 | 15.39% | 6575 | 32875 | 15.19% | -0.2 | -0.005 |  |
# | Admission year | 2020 | 134168 | 670840 | 14.10% | 6628 | 33140 | 15.32% | 1.22 | 0.034 |  |
# | Admission year | 2021 | 134770 | 673850 | 14.16% | 6610 | 33050 | 15.28% | 1.12 | 0.031 |  |
# ...

# %% [markdown]
# ## 6. Complications

# %%
show_step(6)
# Out:
# | complication | no_shock_unweighted_n | no_shock_weighted_n | no_shock_weighted_percent | septic_shock_unweighted_n | septic_shock_weighted_n | septic_shock_weighted_percent | absolute_difference_percentage_points | prevalence_ratio | p_value_unadjusted | p_value_fdr_adjusted | fdr_significant_at_0_05 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Acute respiratory failure | 97756 | 488780 | 10.27 | 21402 | 107010 | 49.46 | 39.19 | 4.82 | <0.001 | <0.001 | True |
# | Acute kidney injury | 225088 | 1125440 | 23.65 | 29248 | 146240 | 67.59 | 43.94 | 2.86 | <0.001 | <0.001 | True |
# | Pneumonia | 146984 | 734920 | 15.44 | 18986 | 94930 | 43.88 | 28.43 | 2.84 | <0.001 | <0.001 | True |
# | Pulmonary embolism | 17981 | 89905 | 1.89 | 1238 | 6190 | 2.86 | 0.97 | 1.51 | <0.001 | <0.001 | True |
# | Acute lower-extremity DVT | 8245 | 41225 | 0.87 | 610 | 3050 | 1.41 | 0.54 | 1.63 | <0.001 | <0.001 | True |
# ...

# %% [markdown]
# ## 7. Overall Documented Inpatient Palliative-Care Utilization

# %%
show_step(7)
# Out:
# | cohort | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent | absolute_difference_pp | crude_odds_ratio_95_ci | p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | All adult HM hospitalizations | 994992 | 80733 | 4974958 | 403665 | 8.11 | 8.06 | 8.17 |  |  |  |
# | HM without septic shock | 951721 | 68813 | 4758603 | 344065 | 7.23 | 7.18 | 7.28 |  |  |  |
# | HM with septic shock | 43271 | 11920 | 216355 | 59600 | 27.55 | 27.13 | 27.97 | 20.32 (19.89–20.74) | 4.878 (4.77–4.989) | <0.001 |
# | Total | 994992 | — | 4974958 | — | — | — | — | — | — | — |
# *Outcome is documented inpatient palliative-care use (Z51.5), not necessarily a consultation.*

# %% [markdown]
# ## 8. Annual Palliative-Care Trends by Septic-Shock Status

# %%
show_step(8)
# Out:
# | year | septic_shock_status | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent | septic_shock_vs_no_shock_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 2016 | No documented Septic shock | 138465 | 8391 | 692325 | 41955 | 6.06 | 5.94 | 6.19 | <0.001 |
# | 2016 | Documented Septic shock | 5706 | 1347 | 28530 | 6735 | 23.61 | 22.52 | 24.73 | <0.001 |
# | 2017 | No documented Septic shock | 138011 | 9014 | 690055 | 45070 | 6.53 | 6.4 | 6.66 | <0.001 |
# | 2017 | Documented Septic shock | 5693 | 1421 | 28465 | 7105 | 24.96 | 23.85 | 26.1 | <0.001 |
# | 2018 | No documented Septic shock | 140419 | 9537 | 702095 | 47685 | 6.79 | 6.66 | 6.92 | <0.001 |
# | 2018 | Documented Septic shock | 6054 | 1590 | 30270 | 7950 | 26.26 | 25.17 | 27.39 | <0.001 |
# ...

# %% [markdown]
# ## 9. Overall HM-Subtype Palliative-Care Utilization

# %%
show_step(9)
# Out:
# | cohort | hm_subtype | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent | overall_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | All adult HM hospitalizations | Lymphoma | 301494 | 23491 | 1507470 | 117455 | 7.79 | 7.7 | 7.89 | <0.001 |
# | All adult HM hospitalizations | AML | 79382 | 10984 | 396910 | 54920 | 13.84 | 13.6 | 14.08 |  |
# | All adult HM hospitalizations | CML | 26540 | 1760 | 132700 | 8800 | 6.63 | 6.34 | 6.94 |  |
# | All adult HM hospitalizations | CLL/chronic leukemia | 108837 | 8272 | 544185 | 41360 | 7.6 | 7.44 | 7.76 |  |
# | All adult HM hospitalizations | ALL/unspecified acute leukemia | 32145 | 2200 | 160725 | 11000 | 6.84 | 6.57 | 7.13 |  |
# | All adult HM hospitalizations | Other leukemia | 20000 | 2031 | 100000 | 10155 | 10.16 | 9.74 | 10.58 |  |
# ...

# %% [markdown]
# ## 10. HM Without Septic Shock

# %%
show_step(10)
# Out:
# | cohort | hm_subtype | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent | overall_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | HM without septic shock | Lymphoma | 288275 | 19649 | 1441375 | 98245 | 6.82 | 6.72 | 6.91 | <0.001 |
# | HM without septic shock | AML | 74307 | 9308 | 371535 | 46540 | 12.53 | 12.29 | 12.77 |  |
# | HM without septic shock | CML | 25629 | 1490 | 128145 | 7450 | 5.81 | 5.53 | 6.11 |  |
# | HM without septic shock | CLL/chronic leukemia | 104344 | 7015 | 521720 | 35075 | 6.72 | 6.57 | 6.88 |  |
# | HM without septic shock | ALL/unspecified acute leukemia | 30661 | 1824 | 153305 | 9120 | 5.95 | 5.69 | 6.22 |  |
# | HM without septic shock | Other leukemia | 18899 | 1710 | 94495 | 8550 | 9.05 | 8.65 | 9.47 |  |
# ...

# %% [markdown]
# ## 11. HM With Septic Shock

# %%
show_step(11)
# Out:
# | cohort | hm_subtype | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent | overall_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | HM with septic shock | Lymphoma | 13219 | 3842 | 66095 | 19210 | 29.06 | 28.3 | 29.84 | <0.001 |
# | HM with septic shock | AML | 5075 | 1676 | 25375 | 8380 | 33.02 | 31.75 | 34.33 |  |
# | HM with septic shock | CML | 911 | 270 | 4555 | 1350 | 29.64 | 26.76 | 32.68 |  |
# | HM with septic shock | CLL/chronic leukemia | 4493 | 1257 | 22465 | 6285 | 27.98 | 26.69 | 29.3 |  |
# | HM with septic shock | ALL/unspecified acute leukemia | 1484 | 376 | 7420 | 1880 | 25.34 | 23.19 | 27.61 |  |
# | HM with septic shock | Other leukemia | 1101 | 321 | 5505 | 1605 | 29.16 | 26.55 | 31.9 |  |
# ...

# %% [markdown]
# ## 12. Primary Adjusted Model

# %%
show_step(12)
# Out:
# | measure | estimate | ci_95 | p_value |
# | --- | --- | --- | --- |
# | Adjusted odds ratio for documented Septic shock | 4.754 | 4.643–4.868 | <0.001 |
# | Adjusted absolute probability difference, percentage points | 18.63 | 18.23–19.04 | <0.001 |
# | Total | — | — | — |
# | septic_shock_status | adjusted_probability_percent | ci_95_lower_percent | ci_95_upper_percent |
# | --- | --- | --- | --- |
# | No documented Septic shock | 7.26 | 7.2 | 7.31 |
# | Documented Septic shock | 25.89 | 25.49 | 26.29 |
# | Total observed cohort | — | — | — |
# *Marginal probabilities average over the observed covariate distribution.*

# %% [markdown]
# ## 13. Decedent Analysis

# %%
show_step(13)
# Out:
# | cohort | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent | septic_shock_comparison_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Decedents without septic shock | 36249 | 20357 | 181245 | 101785 | 56.16 | 55.66 | 56.66 | <0.001 |
# | Decedents with septic shock | 17488 | 8151 | 87440 | 40755 | 46.61 | 45.88 | 47.34 |  |
# | Total decedents | 53737 | 28508 | 268685 | 142540 | 53.05 | 52.64 | 53.46 | <0.001 |

# %% [markdown]
# ## 14. Adjusted Decedent Interaction

# %%
show_step(14)
# Out:
# | hm_subtype | adjusted_probability_no_shock_percent | adjusted_probability_septic_shock_percent | adjusted_difference_pp | difference_ci_95_lower_pp | difference_ci_95_upper_pp | subtype_p_value | overall_interaction_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | Lymphoma | 58.02 | 48.28 | -9.74 | -11.35 | -8.13 | <0.001 | 0.003 |
# | AML | 58.14 | 47.09 | -11.05 | -13.37 | -8.73 | <0.001 |  |
# | CML | 55.85 | 51.41 | -4.45 | -10.35 | 1.46 | 0.140 |  |
# | CLL/chronic leukemia | 53.99 | 45.05 | -8.94 | -11.59 | -6.29 | <0.001 |  |
# | ALL/unspecified acute leukemia | 54.13 | 46.35 | -7.78 | -12.86 | -2.7 | 0.003 |  |
# | Other leukemia | 54.23 | 46.9 | -7.33 | -12.6 | -2.06 | 0.006 |  |
# | Myeloma/plasma-cell neoplasm | 56.38 | 47.75 | -8.63 | -10.94 | -6.31 | <0.001 |  |
# | MDS | 54.12 | 45.84 | -8.27 | -10.93 | -5.62 | <0.001 |  |
# | MPN | 50.85 | 47.97 | -2.88 | -5.79 | 0.03 | 0.052 |  |
# | Total | — | — | — | — | — | — | 0.003 |
# ...

# %% [markdown]
# ## 15. Septic-Shock Decedents by HM Subtype

# %%
show_step(15)
# Out:
# | cohort | hm_subtype | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent | overall_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Septic shock decedents | Lymphoma | 5620 | 2668 | 28100 | 13340 | 47.47 | 46.19 | 48.76 | 0.388 |
# | Septic shock decedents | AML | 2578 | 1221 | 12890 | 6105 | 47.36 | 45.45 | 49.28 |  |
# | Septic shock decedents | CML | 366 | 182 | 1830 | 910 | 49.73 | 44.68 | 54.78 |  |
# | Septic shock decedents | CLL/chronic leukemia | 1895 | 872 | 9475 | 4360 | 46.02 | 43.8 | 48.25 |  |
# | Septic shock decedents | ALL/unspecified acute leukemia | 611 | 264 | 3055 | 1320 | 43.21 | 39.35 | 47.15 |  |
# | Septic shock decedents | Other leukemia | 490 | 229 | 2450 | 1145 | 46.73 | 42.4 | 51.11 |  |
# ...

# %% [markdown]
# ## 16. Overall Annual Trends

# %%
show_step(16)
# Out:
# | year | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 2016 | 144171 | 9738 | 720855 | 48690 | 6.75 | 6.63 | 6.89 |
# | 2017 | 143704 | 10435 | 718520 | 52175 | 7.26 | 7.13 | 7.4 |
# | 2018 | 146473 | 11127 | 732365 | 55635 | 7.6 | 7.46 | 7.73 |
# | 2019 | 153047 | 11817 | 765235 | 59085 | 7.72 | 7.59 | 7.86 |
# | 2020 | 140796 | 12071 | 703980 | 60355 | 8.57 | 8.43 | 8.72 |
# | 2021 | 141380 | 13119 | 706899 | 65595 | 9.28 | 9.13 | 9.43 |
# | 2022 | 125421 | 12426 | 627105 | 62130 | 9.91 | 9.74 | 10.07 |
# | Total, 2016–2022 | 994992 | 80733 | 4974958 | 403665 | 8.11 | 8.06 | 8.17 |
# | Measure | EAPC, % | 95% CI | p-value |
# | --- | --- | --- | --- |
# | Total / overall EAPC | 6.54 | 6.18–6.91 | <0.001 |

# %% [markdown]
# ## 17. Trends by Septic-Shock Status

# %%
show_step(17)
# Out:
# | year | septic_shock_status | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent | within_year_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 2016 | No documented Septic shock | 138465 | 8391 | 692325 | 41955 | 6.06 | 5.94 | 6.19 | <0.001 |
# | 2016 | Documented Septic shock | 5706 | 1347 | 28530 | 6735 | 23.61 | 22.52 | 24.73 | <0.001 |
# | 2017 | No documented Septic shock | 138011 | 9014 | 690055 | 45070 | 6.53 | 6.4 | 6.66 | <0.001 |
# | 2017 | Documented Septic shock | 5693 | 1421 | 28465 | 7105 | 24.96 | 23.85 | 26.1 | <0.001 |
# | 2018 | No documented Septic shock | 140419 | 9537 | 702095 | 47685 | 6.79 | 6.66 | 6.92 | <0.001 |
# | 2018 | Documented Septic shock | 6054 | 1590 | 30270 | 7950 | 26.26 | 25.17 | 27.39 | <0.001 |
# ...

# %% [markdown]
# ## 18. Trends Among Septic-Shock Admissions

# %%
show_step(18)
# Out:
# | hm_subtype | year | unweighted_sample_n | unweighted_palliative_care_n | weighted_hospitalizations | weighted_palliative_care_n | weighted_palliative_care_percent | ci_95_lower_percent | ci_95_upper_percent | subtype_trend_p_value | overall_year_by_subtype_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Lymphoma | 2016 | 1636 | 412 | 8180 | 2060 | 25.18 | 23.14 | 27.34 | <0.001 | 0.010 |
# | Lymphoma | 2017 | 1737 | 456 | 8685 | 2280 | 26.25 | 24.24 | 28.37 | <0.001 |  |
# | Lymphoma | 2018 | 1839 | 509 | 9195 | 2545 | 27.68 | 25.68 | 29.77 | <0.001 |  |
# | Lymphoma | 2019 | 1961 | 578 | 9805 | 2890 | 29.47 | 27.5 | 31.53 | <0.001 |  |
# | Lymphoma | 2020 | 1924 | 591 | 9620 | 2955 | 30.72 | 28.7 | 32.82 | <0.001 |  |
# | Lymphoma | 2021 | 2024 | 647 | 10120 | 3235 | 31.97 | 29.97 | 34.03 | <0.001 |  |
# | Lymphoma | 2022 | 2098 | 649 | 10490 | 3245 | 30.93 | 28.99 | 32.95 | <0.001 |  |
# ...

# %% [markdown]
# ## 19. Septic Shock × HM-Subtype Interaction

# %%
show_step(19)
# Out:
# | Test | Wald chi-square | df | p-value |
# | --- | --- | --- | --- |
# | Septic shock × HM subtype | 179.193 | 8 | <0.001 |
# | Total | — | — | <0.001 |

# %% [markdown]
# ## 20. Subtype-Specific Marginal Effects

# %%
show_step(20)
# Out:
# | hm_subtype | adjusted_probability_no_shock_percent | adjusted_probability_septic_shock_percent | adjusted_absolute_difference_pp | difference_ci_95_lower_pp | difference_ci_95_upper_pp | subtype_p_value | overall_interaction_p_value |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | Lymphoma | 7.24 | 28.6 | 21.36 | 20.6 | 22.13 | <0.001 | <0.001 |
# | AML | 13.94 | 34.69 | 20.75 | 19.42 | 22.07 | <0.001 |  |
# | CML | 5.97 | 27.8 | 21.83 | 18.96 | 24.71 | <0.001 |  |
# | CLL/chronic leukemia | 5.53 | 23.36 | 17.83 | 16.68 | 18.98 | <0.001 |  |
# | ALL/unspecified acute leukemia | 9.58 | 35.2 | 25.63 | 22.89 | 28.37 | <0.001 |  |
# | Other leukemia | 8.5 | 27.36 | 18.86 | 16.27 | 21.46 | <0.001 |  |
# | Myeloma/plasma-cell neoplasm | 7.83 | 25.65 | 17.82 | 16.78 | 18.86 | <0.001 |  |
# | MDS | 6.65 | 23.63 | 16.98 | 15.81 | 18.14 | <0.001 |  |
# | MPN | 5.23 | 19.9 | 14.67 | 13.66 | 15.68 | <0.001 |  |
# | Total | — | — | — | — | — | — | <0.001 |
# ...

# %% [markdown]
# ## 21. BMT/HSCT Modification of the Septic-Shock Association
#
# BMT/HSCT status is diagnosis-based: Z94.81 or Z94.84 in any diagnosis position. The source extract has no procedure-code fields, so inpatient HSCT procedures cannot be identified.

# %%
show_step(21)
# Out:
# # BMT/HSCT Modification of the Association Between Septic Shock and Documented Inpatient Palliative-Care Use
#
# **Primary outcome:** Documented inpatient palliative-care use, defined as ICD-10-CM `Z51.5` in any diagnosis position.
#
# **Primary exposure:** Documented septic shock, defined as ICD-10-CM `R65.21` in any diagnosis position.
#
# **Effect modifier:** Diagnosis-based BMT/HSCT status, defined as ICD-10-CM `Z94.81` or `Z94.84` in any diagnosis position.
#
# ## Four-Group Descriptive Results
#
# | BMT/HSCT and septic-shock group | Unweighted n | Unweighted PC events | Weighted n, 2016–2022 | Weighted PC events | Weighted PC prevalence | Adjusted overall group p-value |
# | --- | ---: | ---: | ---: | ---: | ---: | ---: |
# | No BMT, no septic shock | 910,772 | 65,895 | 4,553,858 | 329,475 | 7.24% |  |
# | No BMT, septic shock | 40,743 | 11,227 | 203,715 | 56,135 | 27.56% |  |
# | BMT, no septic shock | 40,949 | 2,918 | 204,745 | 14,590 | 7.13% |  |
# ...
