# %% [markdown]
# # Demographic smoke test
#
# Counts NIS inpatient discharges for Asian/Pacific Islander females ages 0–10. NIS records discharges, not unique patients.
#
# Click the **Run** (▶) button for the cell below, or choose **Run → Run All Cells**. Unchanged reruns use the cached aggregate.

# %%
from pathlib import Path
import os
import sys

# Work whether Jupyter opens in the repository root or notebooks directory.
repo_root = Path.cwd()
if not (repo_root / "scripts").is_dir():
    repo_root = repo_root.parent
if not (repo_root / "scripts/count_young_asian_female_discharges.py").is_file():
    raise RuntimeError("Open this notebook from the IPC-MPC-Study repository.")

os.chdir(repo_root)
sys.path.insert(0, str(repo_root))
from scripts.count_young_asian_female_discharges import main

main([])
# Out:
# {
#   "analysis": "Asian/Pacific Islander female discharges, ages 0 through 10",
#   "unit": "NIS inpatient discharge (not a unique patient)",
#   "discharge_count": 148632,
#   "weighted_national_estimate": 743159.5920303989,
#   "filters": {
#     "FEMALE": 1,
#     "RACE": 4,
#     "AGE": "< 11"
#   },
#   "dataset_file_count": 144,
#   "dataset_fingerprint": "9a5f736deb8e0ee69ce6e74a02f6387dc414d2190a497d148d8eb9686b754b93",
#   "computed_at_utc": "2026-07-20T15:50:06.263501+00:00",
#   "cache_used": true
# }
